# %%
# !pip install pandas matplotlib seaborn scikit-learn
# Out:
# zsh:1: command not found: pip

# %%
# !pip3install pandas matplotlib seaborn scikit-learn
# Out:
# zsh:1: command not found: pip3install

# %%
# !pip3 install pandas matplotlib seaborn scikit-learn

# %%
import pandas as pd
data = pd.read_csv('/Users/omarsamy/Downloads/2025-VeloCityX-Expanded-Fan-Engagement-Data.csv')
data.head()
# Out:
#   User ID  Fan Challenges Completed  Predictive Accuracy (%)  \
# 0    U001                         5                       80
# 1    U002                         8                       60
# 2    U003                         3                       90
# 3    U004                         7                       70
# 4    U005                         2                       50
#
#    Virtual Merchandise Purchases  Sponsorship Interactions (Ad Clicks)  \
# 0                              3                                    10
# 1                              1                                     8
# 2                              0                                     6
# 3                              2                                    15
# 4                              5                                     3
#
#    Time on Live 360 (mins)  Real-Time Chat Activity (Messages Sent)
# 0                      120                                       20
# ...

# %%
# Check for missing values
print(data.isnull().sum())

# Check for duplicate rows
print(data.duplicated().sum())
# Out:
# User ID                                    0
# Fan Challenges Completed                   0
# Predictive Accuracy (%)                    0
# Virtual Merchandise Purchases              0
# Sponsorship Interactions (Ad Clicks)       0
# Time on Live 360 (mins)                    0
# Real-Time Chat Activity (Messages Sent)    0
# dtype: int64
# 0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot a heatmap to show the correlation between different columns
plt.figure(figsize=(10, 6))
sns.heatmap(data.corr(), annot=True)
plt.show()

# %%
# !pip3 install seaborn matplotlib

# %%
numeric_data = data.select_dtypes(include=['float64', 'int64'])

plt.figure(figsize=(10, 6))
sns.heatmap(numeric_data.corr(), annot=True)
plt.show()

# %%
# Select only numeric columns for the groupby operation
numeric_data = data.select_dtypes(include=['float64', 'int64'])

# Group by 'Virtual Merchandise Purchases' and calculate the mean for numeric columns
merchandise_analysis = numeric_data.groupby(data['Virtual Merchandise Purchases']).mean()

# Display insights
print(merchandise_analysis)
# Out:
#                                Fan Challenges Completed  \
# Virtual Merchandise Purchases
# 0                                              5.400000
# 1                                              5.142857
# 2                                              5.705882
# 3                                              5.764706
# 4                                              5.833333
# 5                                              6.333333
# 6                                              6.642857
#
#                                Predictive Accuracy (%)  \
# Virtual Merchandise Purchases
# 0                                            75.950000
# 1                                            73.714286
# 2                                            74.294118
# 3                                            74.176471
# 4                                            80.333333
# 5                                            69.583333
# 6                                            79.071429
#
# ...

# %%
import matplotlib.pyplot as plt

# Plot the clusters based on two features for visualization
plt.scatter(data['Fan Challenges Completed'], data['Virtual Merchandise Purchases'], c=data['Cluster'], cmap='viridis')
plt.xlabel('Fan Challenges Completed')
plt.ylabel('Virtual Merchandise Purchases')
plt.title('Clusters of Users based on Fan Challenges and Merchandise Purchases')
plt.colorbar(label='Cluster')
plt.show()

# %%
# Get cluster centers
cluster_centers = kmeans.cluster_centers_
print("Cluster Centers:\n", cluster_centers)
# Out:
# Cluster Centers:
#  [[  6.41176471   2.47058824 121.26470588]
#  [  5.53846154   2.79487179 169.97435897]
#  [  5.37037037   2.74074074  80.85185185]]

# %%
from sklearn.preprocessing import StandardScaler

# Scale the features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# Apply KMeans clustering on scaled features
kmeans = KMeans(n_clusters=3)
data['Cluster'] = kmeans.fit_predict(scaled_features)

# %%
### Objective:
The goal of the "Race Talk MVP" challenge is to increase real-time chat engagement during races. Fans will be rewarded for actively participating in chat, which can help boost interactions with sponsorships and increase ad click-through rates.

### Challenge Rules:
- Fans must send at least **50 messages** during a race to qualify for rewards.
- An additional prize will be awarded to the fan with the **most engaging comment**, determined by the number of likes or responses from others in the chat.

### Outcome Prediction:
Based on the correlation analysis, **Real-Time Chat Activity** has a positive correlation (0.19) with **Sponsorship Interactions (Ad Clicks)**. Encouraging fans to engage more in chat could lead to increased ad interactions, boosting sponsorship monetization.

### Justification:
From the data, we see that users who participate in real-time chat tend to interact more with sponsorship ads. By motivating users to participate in chat, we can drive higher engagement with sponsorships, leading to increased monetization for VeloCityX.
